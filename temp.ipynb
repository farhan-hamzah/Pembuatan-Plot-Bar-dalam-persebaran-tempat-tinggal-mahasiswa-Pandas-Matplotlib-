# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataMhs = {
    'nama': ['Andi', 'Budi', 'Citra', 'Dian', 'Eka', 'Fani', 'Gita', 'Hana', 'Ira', 'Joko'],
    'umur': [20, 21, 19, 22, 20, 21, 19, 20, 21, 22],
    'nilai_matematika': [85, 78, 92, 88, 75, 89, 91, 83, 87, 79],
    'nilai_fisika': [80, 85, 88, 90, 72, 86, 89, 81, 84, 77],
    'nilai_kimia': [78, 82, 85, 87, 70, 83, 86, 79, 81, 75],
    'asal_kota': ['Jakarta', 'Bandung', 'Surabaya', 'Jakarta', 'Bandung', 
                  'Surabaya', 'Jakarta', 'Bandung', 'Surabaya', 'Jakarta']
}

# %%
data = pd.DataFrame(dataMhs)

# %%
dataPerkota = data.groupby('asal_kota').count()

# %%
NamaMhsPerkota = dataPerkota['nama']

# %%
NamaMhsPerkota.plot.bar()
# Out:
# <Axes: xlabel='asal_kota'>
